# %%
#2

import json
import os
import shutil
import zipfile
import requests
# !mkdir /tmp/LORAS
dia = "21-03-2024"
model_type = "XL"
json_file = "/home/studio-lab-user/ComfyUI/output.json"
save_path = "/tmp/LORAS"


# Carregar o arquivo JSON


with open(json_file, 'r') as f:
    data = json.load(f)

# Iterar sobre os objetos no JSON
for item in data:
    token = item.get('token')
    # Criar o link do arquivo ZIP
    zip_link = f"https://huggingface.co/adbrasi/akarris_trainer/resolve/main/{dia}/{token}{model_type}.zip"

    print(f"Link:{zip_link}")
    


    # BAIXA O ARQUIVO ZIP E EXTRAI E SALVA NA VARIAVEL OS CAMINHOS
    import os
    import shutil

    link = zip_link
    link = link.replace("?download=true", "")


    # Verificar arquivos antes de baixar
    files_before_download = os.listdir(save_path)


    # Baixar o arquivo
    # !wget {link} --header="Authorization: Bearer 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" -P {save_path}

    # Verificar arquivos depois de baixar
    files_after_download = os.listdir(save_path)


    # Encontrar o arquivo baixado
    downloaded_file = None
    for file in files_after_download:
        if file not in files_before_download:
            downloaded_file = file
            break

    # Salvar o caminho do arquivo baixado em uma variável
    if downloaded_file:
        downloaded_file_path = os.path.join(save_path, downloaded_file)
        print("Caminho do arquivo baixado:", downloaded_file_path)
    else:
        print("Nenhum arquivo novo encontrado após o download.")


    import zipfile
    import os

    def extrair_arquivo_zip(caminho_zip, pasta_destino):
        with zipfile.ZipFile(caminho_zip, 'r') as zip_ref:
            zip_ref.extractall(pasta_destino)

        return pasta_destino

    # Exemplo de uso
    caminho_arquivo_zip = downloaded_file_path


    nome_arquivo_zip = os.path.basename(caminho_arquivo_zip)
    nome_arquivo_sem_zip = nome_arquivo_zip.replace(".zip", "")
    print(nome_arquivo_sem_zip)


    pasta_destino = f'{save_path}'
    caminho_pasta_extraida = extrair_arquivo_zip(caminho_arquivo_zip, pasta_destino)
    print(f'A pasta foi extraída em: {caminho_pasta_extraida}')
    # !rm {caminho_arquivo_zip}
    
    
import os
# !mkdir /home/studio-lab-user/ComfyUI/models/inpaint
# Definir as operações com as pastas de origem e destino
operations = [
    {
        'source_folder': '/tmp/ipadapter-model',
        'destination_folder': '/home/studio-lab-user/ComfyUI/custom_nodes/ComfyUI_IPAdapter_plus/models'
    },
    {
        'source_folder': '/tmp/clip-vision',
        'destination_folder': '/home/studio-lab-user/ComfyUI/models/clip_vision'
    },
    {
        'source_folder': '/tmp/controlnet',
        'destination_folder': '/home/studio-lab-user/ComfyUI/models/controlnet'
    },
    {
        'source_folder': '/tmp/Stable-diffusion',
        'destination_folder': '/home/studio-lab-user/ComfyUI/models/checkpoints'
    },
    {
        'source_folder': '/tmp/animatediff',
        'destination_folder': '/home/studio-lab-user/ComfyUI/custom_nodes/ComfyUI-AnimateDiff-Evolved/models'
    },
    {
        'source_folder': '/tmp/VAE',
        'destination_folder': '/home/studio-lab-user/ComfyUI/models/vae'
    },
    {
        'source_folder': '/tmp/LORAS',
        'destination_folder': '/home/studio-lab-user/ComfyUI/models/loras'
    },
    {
        'source_folder': '/tmp/controlnet',
        'destination_folder': '/home/studio-lab-user/ComfyUI/custom_nodes/ControlNet-LLLite-ComfyUI/models'
    },
    # Adicionando a nova operação
    {
        'source_folder': '/tmp/foocus',
        'destination_folder': '/home/studio-lab-user/ComfyUI/models/inpaint'
    },
    {
        'source_folder': '/tmp/upscale',
        'destination_folder': '/home/studio-lab-user/ComfyUI/models/upscale_models'
    }
]

# Iterar sobre as operações e criar os links simbólicos
for operation in operations:
    source_folder = operation.get('source_folder')
    destination_folder = operation.get('destination_folder')

    if not source_folder or not destination_folder:
        print("A pasta de origem ou a pasta de destino não foi especificada corretamente.")
        continue

    if not os.path.exists(destination_folder):
        try:
            os.makedirs(destination_folder)
        except OSError as e:
            print(f"Erro ao criar a pasta de destino {destination_folder}: {e}")
            continue

    if not os.path.exists(source_folder):
        print(f"A pasta de origem {source_folder} não existe.")
        continue

    for root, _, files in os.walk(source_folder):
        for file in files:
            source_file = os.path.join(root, file)
            destination_file = os.path.join(destination_folder, file)

            try:
                if not os.path.exists(destination_file):
                    os.symlink(source_file, destination_file)
            except Exception as e:
                print(f"Erro ao criar o link simbólico para {destination_file}: {e}")

print("Operações concluídas.")
# Out:
# mkdir: cannot create directory '/tmp/LORAS': File exists
# Link:https://huggingface.co/adbrasi/akarris_trainer/resolve/main/21-03-2024/whxXL.zip
# --2024-03-22 15:24:27--  https://huggingface.co/adbrasi/akarris_trainer/resolve/main/21-03-2024/whxXL.zip
# Resolving huggingface.co (huggingface.co)... 3.160.5.76, 3.160.5.109, 3.160.5.25, ...
# Connecting to huggingface.co (huggingface.co)|3.160.5.76|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# ...

# %%
#3

import os
import json

def add_lora_path(json_data):
    for item in json_data:
        token = item.get("token")
        if token:
            lora_file = find_lora_file(token)
            if lora_file:
                item["lora_file"] = lora_file

def find_lora_file(token):
    for root, dirs, files in os.walk(loras_path):
        for file in files:
            if file.endswith(".safetensors") and token in file:
                return file
    return None

# Definir o caminho para a pasta loras_path
loras_path = "/home/studio-lab-user/ComfyUI/models/loras"

# Carregar o arquivo JSON
with open(json_file, "r") as f:
    data = json.load(f)

# Adicionar o nome do arquivo Lora
add_lora_path(data)

# Escrever de volta no arquivo JSON
with open(json_file, "w") as f:
    json.dump(data, f, indent=4)



import os
import json


# Definir o caminho para salvar o arquivo .txt
output_directory = "/home/studio-lab-user/ComfyUI/custom_nodes/ComfyUI-Impact-Pack/wildcards/wildcards_allinone"
output_file = "tokens_lora.txt"

def extract_tokens(json_data):
    tokens = []
    for item in json_data:
        token = item.get("token")
        if token:
            tokens.append(token)
    return tokens

# Criar o diretório de saída se não existir
if not os.path.exists(output_directory):
    os.makedirs(output_directory)

# Carregar o arquivo JSON
with open(json_file, "r") as f:
    data = json.load(f)

# Extrair os tokens do JSON
tokens = extract_tokens(data)

# Caminho completo para o arquivo de saída
output_path = os.path.join(output_directory, output_file)

# Escrever os tokens em um arquivo .txt
with open(output_path, "w") as f:
    for token in tokens:
        f.write(token + "\n")

print("Arquivo tokens_lora.txt criado em", output_path)
# Out:
# Arquivo tokens_lora.txt criado em /home/studio-lab-user/ComfyUI/custom_nodes/ComfyUI-Impact-Pack/wildcards/wildcards_allinone/tokens_lora.txt
